# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import image module
from IPython.display import Image
  
# get the image
Image(url="SVM.jpg", width=750, height=750)
# Out:
# <img src="SVM.jpg" width="750" height="750"/>

# %% [markdown]
# # SVM = Where a hyperplane distinguishes two labels

# %%
df = pd.read_csv('mouse_viral_study.csv')

# %%
df
# Out:
#      Med_1_mL  Med_2_mL  Virus Present
# 0    6.508231  8.582531              0
# 1    4.126116  3.073459              1
# 2    6.427870  6.369758              0
# 3    3.672953  4.905215              1
# 4    1.580321  2.440562              1
# ..        ...       ...            ...
# 395  2.884122  3.271748              1
# 396  7.290855  9.488672              0
# 397  7.895325  8.272529              0
# 398  2.690592  2.674979              1
# 399  7.587821  9.473968              0
#
# [400 rows x 3 columns]

# %%
sns.scatterplot(x='Med_1_mL',y='Med_2_mL',hue='Virus Present',
               data=df)

#HYPERPLANE
x=np.linspace(0,10,100)
m=-1
b=11
y=m*x +b

plt.plot(x,y,'black');

# %% [markdown]
# ## Changing the bias of line

# %%
from sklearn.svm import SVC

# %%
help(SVC)
# Out:
# Help on class SVC in module sklearn.svm._classes:
#
# class SVC(sklearn.svm._base.BaseSVC)
#  |  SVC(*, C=1.0, kernel='rbf', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', break_ties=False, random_state=None)
#  |
#  |  C-Support Vector Classification.
#  |
#  |  The implementation is based on libsvm. The fit time scales at least
#  |  quadratically with the number of samples and may be impractical
#  |  beyond tens of thousands of samples. For large datasets
#  |  consider using :class:`~sklearn.svm.LinearSVC` or
#  |  :class:`~sklearn.linear_model.SGDClassifier` instead, possibly after a
#  |  :class:`~sklearn.kernel_approximation.Nystroem` transformer or
#  |  other :ref:`kernel_approximation`.
#  |
#  |  The multiclass support is handled according to a one-vs-one scheme.
#  |
#  |  For details on the precise mathematical formulation of the provided
# ...

# %%
y = df['Virus Present']

# %%
X = df.drop('Virus Present',axis=1)

# %%
model = SVC(kernel='linear',C=1000) #Inversely proportional to C

# %%
model.fit(X,y)
# Out:
# SVC(C=1000, kernel='linear')

# %%
from svm_margin_plot import plot_svm_boundary #From file

# %%
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model =SVC(kernel='linear',C=0.05)
model.fit(X,y)
# Out:
# SVC(C=0.05, kernel='linear')

# %%
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model =SVC(kernel='linear',C=0.0005)
model.fit(X,y)
# Out:
# SVC(C=0.0005, kernel='linear')

# %%
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Do Cross Validation for getting the right C

# %% [markdown]
# # Radial Basis Function

# %%
model = SVC(kernel='rbf',C=1)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ### Gamma

# %%
model = SVC(kernel='rbf',C=1,gamma='auto') #Auto is 0.5
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='rbf',C=1,gamma=0.9)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='rbf',C=1,gamma=2)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='sigmoid')
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='poly',degree=1)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
model = SVC(kernel='poly',degree=2)
model.fit(X,y)
plot_svm_boundary(model,X,y)
# Out:
# C:\Users\Ashut\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import GridSearchCV

# %%
svm = SVC()
param_grid = {'C':[0.01,0.1,1],'kernel':['linear','rbf']}

# %%
grid = GridSearchCV(svm,param_grid)

# %%
grid.fit(X,y)
# Out:
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 0.1, 1], 'kernel': ['linear', 'rbf']})

# %%
grid.best_params_
# Out:
# {'C': 0.01, 'kernel': 'linear'}

# %% [markdown]
# ## 0.01 is the best kernel for it
